# %%
import pandas as pd 
import glob

from random import choices

# %%
imgs = glob.glob("/share/ju/nexar_data/2023/2023-09-29/*/frames/*.jpg")

# %%
sample = choices(imgs, k=1000)

# %%
print(sample)
# Out:
# ['/share/ju/nexar_data/2023/2023-09-29/604222324882800639/frames/57471e79a809c27764d83944aff80660.jpg', '/share/ju/nexar_data/2023/2023-09-29/604222324748582911/frames/f40be4a971b3c2e96b043ec05c292eb9.jpg', '/share/ju/nexar_data/2023/2023-09-29/604222325419671551/frames/6da4d1d9da92ac6d243e28e7449617c1.jpg', '/share/ju/nexar_data/2023/2023-09-29/604222347834032127/frames/f0dc202ce792d41fdf77cb0a71ff02e1.jpg', '/share/ju/nexar_data/2023/2023-09-29/604222324748582911/frames/d904083868c70eace1d8d990546916b2.jpg', '/share/ju/nexar_data/2023/2023-09-29/604222323809058815/frames/e78aba521873a1beebe5bdd4a9218cd6.jpg', '/share/ju/nexar_data/2023/2023-09-29/604222323809058815/frames/d03e520e54e359cdfc0f0cbf806df8b0.jpg', '/share/ju/nexar_data/2023/2023-09-29/604222337365049343/frames/cdde336f2d057dde0650b69dca70e5b5.jpg', '/share/ju/nexar_data/2023/2023-09-29/604222324882800639/frames/bb66b4de00f4425f02ea781f3d4e98c2.jpg', '/share/ju/nexar_data/2023/2023-09-29/604222325017018367/frames/d4e6ae
# ...

# %%
# make df with sample
df = pd.DataFrame(sample, columns=['img_path'])

# %%
df
# Out:
#                                               img_path
# 0    /share/ju/nexar_data/2023/2023-09-29/604222324...
# 1    /share/ju/nexar_data/2023/2023-09-29/604222324...
# 2    /share/ju/nexar_data/2023/2023-09-29/604222325...
# 3    /share/ju/nexar_data/2023/2023-09-29/604222347...
# 4    /share/ju/nexar_data/2023/2023-09-29/604222324...
# ..                                                 ...
# 995  /share/ju/nexar_data/2023/2023-09-29/604222324...
# 996  /share/ju/nexar_data/2023/2023-09-29/604222324...
# 997  /share/ju/nexar_data/2023/2023-09-29/604222321...
# 998  /share/ju/nexar_data/2023/2023-09-29/604222352...
# 999  /share/ju/nexar_data/2023/2023-09-29/604222325...
#
# [1000 rows x 1 columns]

# %%
# save df
df.to_csv('/share/ju/urbanECG/output/street_flooding/random_flooding_sample.csv', index=False)
